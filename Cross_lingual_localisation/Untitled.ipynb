# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
y, sr = librosa.load("/home/kayode/data/Flickr8k_Yoruba_v6/flickr_audio_yoruba_test/S001_106490881_5a2dd9b7bd_0.wav")    
fig, ax = plt.subplots()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
plt.plot(y)

# %%
y, sr = librosa.load("/home/kayode/data/flickr_audio/wavs/106490881_5a2dd9b7bd_0.wav")    
fig, ax = plt.subplots()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
plt.plot(y)

# %%
def plot_audio(ax, wave_path):
    audio, _ = librosa.load(wave_path, sr=16_000)
    ax.plot(audio)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.set_xlim([0, len(audio)])
    ax.set_xticks([])
    ax.set_yticks([])

# %%
fig, axs = plt.subplots(1, 1, figsize=(35, 5))
plot_audio(axs, "/home/kayode/data/Flickr8k_Yoruba_v6/flickr_audio_yoruba_test/S001_106490881_5a2dd9b7bd_0.wav")

# %%
fig, axs = plt.subplots(1, 1, figsize=(35, 5))
plot_audio(axs, "/home/kayode/data/flickr_audio/wavs/106490881_5a2dd9b7bd_0.wav")

# %%
fig, axs = plt.subplots(1, 1, figsize=(35, 5))
plot_audio(axs, "/home/kayode/data/Flickr8k_Yoruba_v6/flickr_audio_yoruba_test/S001_189721896_1ffe76d89e_0.wav")

# %%
fig, axs = plt.subplots(1, 1, figsize=(35, 5))
plot_audio(axs, "/home/kayode/data/flickr_audio/wavs/189721896_1ffe76d89e_0.wav")

# %%
from PIL import Image

# %%
image = Image.open('/home/kayode/data/Flicker8k_Dataset/270816949_ffad112278.jpg')
new_image = image.resize((200, 200))
new_image.save('image_400.jpg')

# %%
S001_270816949_ffad112278_0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 S001_270816949_ffad112278_0
#
# NameError: name 'S001_270816949_ffad112278_0' is not defined

# %%
fig, axs = plt.subplots(1, 1, figsize=(35, 5))
plot_audio(axs, "/home/kayode/data/Flickr8k_Yoruba_v6/flickr_audio_yoruba_test/S001_270816949_ffad112278_0.wav")

# %%
fig, axs = plt.subplots(1, 1, figsize=(35, 5))
plot_audio(axs, "/home/kayode/data/flickr_audio/wavs/270816949_ffad112278_0.wav")
