# %%
import numpy as np

# %%
a = np.load("outputs/full_all_utt_seg_score.npz", allow_pickle=True)
b = np.load("outputs/full_all_utt_segment_dur.npz", allow_pickle=True)
c = np.load("outputs/full_proposed_max_durations.npz", allow_pickle=True)

# %%
sorted(a.keys())
# Out:
# ['1056338697_4f7d7ce270_0',
#  '1056338697_4f7d7ce270_1',
#  '1056338697_4f7d7ce270_2',
#  '1056338697_4f7d7ce270_3',
#  '1056338697_4f7d7ce270_4',
#  '106490881_5a2dd9b7bd_0',
#  '106490881_5a2dd9b7bd_1',
#  '106490881_5a2dd9b7bd_2',
#  '106490881_5a2dd9b7bd_3',
#  '106490881_5a2dd9b7bd_4',
#  '1082379191_ec1e53f996_0',
#  '1082379191_ec1e53f996_1',
#  '1082379191_ec1e53f996_2',
#  '1082379191_ec1e53f996_3',
#  '1082379191_ec1e53f996_4',
#  '1084040636_97d9633581_0',
#  '1084040636_97d9633581_1',
#  '1084040636_97d9633581_2',
#  '1084040636_97d9633581_3',
#  '1084040636_97d9633581_4',
#  '1096395242_fc69f0ae5a_0',
#  '1096395242_fc69f0ae5a_1',
#  '1096395242_fc69f0ae5a_2',
#  '1096395242_fc69f0ae5a_3',
#  '1096395242_fc69f0ae5a_4',
#  '1107246521_d16a476380_0',
#  '1107246521_d16a476380_1',
#  '1107246521_d16a476380_2',
#  '1107246521_d16a476380_3',
#  '1107246521_d16a476380_4',
#  '1119015538_e8e796281e_0',
#  '1119015538_e8e796281e_1',
#  '1119015538_e8e796281e_2',
# ...

# %%
a["2340206885_58754a799a_2"].shape
# Out:
# (70, 67)

# %%
b["2340206885_58754a799a_2"].shape
# Out:
# (70, 2)

# %%
c["2340206885_58754a799a_2"].shape
# Out:
# (67,)
